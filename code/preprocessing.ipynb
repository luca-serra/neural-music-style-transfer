# %%
# !pip install pretty_midi

# %%
from collections import defaultdict
import copy
from math import log, floor, ceil
import pprint
import matplotlib.pyplot as plt
import pretty_midi
import mido
from mido import MidiFile, MidiTrack, Message, MetaMessage
import numpy as np
import random

# %%
DEBUG = False

# The MIDI pitches we use.
PITCHES = range(24,108)
OFFSET = 109-21
PITCHES_MAP = { p : i for i, p in enumerate(PITCHES) }
print(len(PITCHES))
# Out:
# 84

# %%
def nearest_pow2(x):
    '''Normalize input to nearest power of 2, or midpoints between
    consecutive powers of two. Round down when halfway between two
    possibilities.'''

    low = 2**int(floor(log(x, 2)))
    high = 2**int(ceil(log(x, 2)))
    mid = (low + high) / 2

    if x < mid:
        high = mid
    else:
        low = mid
    if high - x < x - low:
        nearest = high
    else:
        nearest = low
    return nearest

# %%
def get_note_track(mid_file):
    '''Given a MIDI object, return the first track with note events.'''
    midi_tracks = mid_file.tracks
    for i, track in enumerate(midi_tracks):
        for msg in track:
            if msg.type == 'note_on':
                return i, track
    raise ValueError(
        'MIDI object does not contain any tracks with note messages.')

def quantize_tick(tick, ticks_per_quarter, quantization):
    '''Quantize the timestamp or tick.
    Arguments:
    tick -- An integer timestamp
    ticks_per_quarter -- The number of ticks per quarter note
    quantization -- The note duration, represented as 1/2**quantization
    '''
    assert (ticks_per_quarter * 4) % 2 ** quantization == 0, \
        'Quantization too fine. Ticks per quantum must be an integer.'
    ticks_per_quantum = (ticks_per_quarter * 4) / float(2 ** quantization)
    quantized_ticks = int(
        round(tick / float(ticks_per_quantum)) * ticks_per_quantum)
    return quantized_ticks

def unquantize(mid, style_mid):
    unquantized_mid = copy.deepcopy(mid)
    # By convention, Track 0 contains metadata and Track 1 contains
    # the note on and note off events.
    orig_note_track_idx, orig_note_track = get_note_track(mid)
    style_note_track_idx, style_note_track = get_note_track(style_mid)

    note_track = unquantize_track(orig_note_track, style_note_track)
    unquantized_mid.tracks[orig_note_track_idx] = note_track

    return unquantized_mid

def unquantize_track(orig_track, style_track):
    '''Returns the unquantised orig_track with encoded velocities from the style_track.
    Arguments:
    orig_track -- Non-quantised MIDI object
    style_track -- Quantised and stylised MIDI object '''

    first_note_msg_idx = None

    for i, msg in enumerate(orig_track):
        if msg.type == 'note_on':
            orig_first_note_msg_idx = i
            break

    for i, msg in enumerate(style_track):
        if msg.type == 'note_on':
            style_first_note_msg_idx = i
            break

    orig_cum_msgs = zip(
        np.cumsum([msg.time for msg in orig_track[orig_first_note_msg_idx:]]),
        [msg for msg in orig_track[orig_first_note_msg_idx:]])

    style_cum_msgs = zip(
        np.cumsum([msg.time for msg in style_track[style_first_note_msg_idx:]]),
        [msg for msg in style_track[style_first_note_msg_idx:]])

    # orig_cum_msgs.sort(key=lambda (cum_time, msg): cum_time)
    # style_cum_msgs.sort(key=lambda (cum_time, msg): cum_time)
    orig_cum_msgs.sort(key=lambda x: x[0])
    style_cum_msgs.sort(key=lambda x: x[0])

    open_msgs = defaultdict(list)

    for cum_time, msg in orig_cum_msgs:
        if msg.type == 'note_on' and msg.velocity > 0:
            open_msgs[msg.note].append((cum_time,msg))

    for i, (cum_time, msg) in enumerate(style_cum_msgs):
         if msg.type == 'note_on' and msg.velocity > 0:
            note_on_open_msgs = open_msgs[msg.note]
            note_on_cum_time, note_on_msg = note_on_open_msgs[0]
            note_on_msg.velocity = msg.velocity
            open_msgs[msg.note] = note_on_open_msgs[1:]

    return orig_track

def quantize(mid, quantization=5):
    '''Return a midi object whose notes are quantized to
    1/2**quantization notes.
    Arguments:
    mid -- MIDI object
    quantization -- The note duration, represented as
      1/2**quantization.'''

    quantized_mid = copy.deepcopy(mid)
    # By convention, Track 0 contains metadata and Track 1 contains
    # the note on and note off events.
    note_track_idx, note_track = get_note_track(mid)

    new_track = quantize_track( note_track, mid.ticks_per_beat, quantization)
    if new_track == None:
        return None
    quantized_mid.tracks[note_track_idx] = new_track
    return quantized_mid

def quantize_track(track, ticks_per_quarter, quantization):
    '''Return the differential time stamps of the note_on, note_off, and
    end_of_track events, in order of appearance, with the note_on events
    quantized to the grid given by the quantization.
    Arguments:
    track -- MIDI track containing note event and other messages
    ticks_per_quarter -- The number of ticks per quarter note
    quantization -- The note duration, represented as
      1/2**quantization.'''

    pp = pprint.PrettyPrinter()

    # Message timestamps are represented as differences between
    # consecutive events. Annotate messages with cumulative timestamps.

    # Assume the following structure:
    # [header meta messages] [note messages] [end_of_track message]
    first_note_msg_idx = None
    for i, msg in enumerate(track):
        if msg.type == 'note_on':
            first_note_msg_idx = i
            break

    cum_msgs = list(zip(
        np.cumsum([msg.time for msg in track[first_note_msg_idx:]]),
        [msg for msg in track[first_note_msg_idx:]]))
    

    end_of_track_cum_time = cum_msgs[-1][0]
 
    quantized_track = MidiTrack()
    quantized_track.extend(track[:first_note_msg_idx])
    # Keep track of note_on events that have not had an off event yet.
    # note number -> message
    open_msgs = defaultdict(list)
    quantized_msgs = []
    for cum_time, msg in cum_msgs:
        if DEBUG:
            print('Message:', msg)
            print ('Open messages:')
            pp.pprint(open_msgs)
        if msg.type == 'note_on' and msg.velocity > 0:
            # Store until note off event. Note that there can be
            # several note events for the same note. Subsequent
            # note_off events will be associated with these note_on
            # events in FIFO fashion.
            open_msgs[msg.note].append((cum_time, msg))
        elif msg.type == 'note_off' or (msg.type == 'note_on' and msg.velocity == 0):
            # assert msg.note in open_msgs, \
            #     'Bad MIDI. Cannot have note off event before note on event'

            if msg.note not in open_msgs:
                 print('Bad MIDI. Cannot have note off event before note on event')
                 return
            
            note_on_open_msgs = open_msgs[msg.note]

            if len(note_on_open_msgs) == 0:

                print('Bad MIDI, Note has no end time.')
                return

            # assert len(note_on_open_msgs) > 0, 'Bad MIDI, Note has no end time.'

            note_on_cum_time, note_on_msg = note_on_open_msgs[0]
            open_msgs[msg.note] = note_on_open_msgs[1:]

            # Quantized note_on time
            quantized_note_on_cum_time = quantize_tick(
                note_on_cum_time, ticks_per_quarter, quantization)

            # The cumulative time of note_off is the quantized
            # cumulative time of note_on plus the orginal difference
            # of the unquantized cumulative times.
            quantized_note_off_cum_time = quantized_note_on_cum_time + (cum_time - note_on_cum_time)
            quantized_msgs.append((min(end_of_track_cum_time, quantized_note_on_cum_time), note_on_msg))
            quantized_msgs.append((min(end_of_track_cum_time, quantized_note_off_cum_time), msg))

            if DEBUG:
                print('Appended', quantized_msgs[-2:])
        elif msg.type == 'end_of_track':
            quantized_msgs.append((cum_time, msg))

        if DEBUG:
            print('\n')

    # Now, sort the quantized messages by (cumulative time,
    # note_type), making sure that note_on events come before note_off
    # events when two event have the same cumulative time. Compute
    # differential times and construct the quantized track messages.
    
    # quantized_msgs.sort(
    #     key=lambda (cum_time, msg): cum_time
    #     if (msg.type=='note_on' and msg.velocity > 0) else cum_time + 0.5)

    quantized_msgs.sort(key=lambda x: x[0])
    # for x in quantized_msgs:
    #   msg = x[1]                       ???????
    #   if not(msg.type=='note_on' and msg.velocity > 0):
    #     x[0] += 0.5 

    diff_times = [quantized_msgs[0][0]] + list(
        np.diff([ msg[0] for msg in quantized_msgs ]))
    for diff_time, (cum_time, msg) in zip(diff_times, quantized_msgs):
        quantized_track.append(msg.copy(time=diff_time))
    if DEBUG:
        print('Quantized messages:')
        pp.pprint(quantized_msgs)
        pp.pprint(diff_times)
    return quantized_track

# %%
def midi_to_array_one_hot(mid, quantization):
    '''Return array representation of a 4/4 time signature, MIDI object.
    Normalize the number of time steps in track to a power of 2. Then
    construct a T x N*2 array A (T = number of time steps, N = number of
    MIDI note numbers) where [A(t,n), A(t, n+1)] is the state of the note number
    at time step t.
    Arguments:
    mid -- MIDI object with a 4/4 time signature
    quantization -- The note duration, represented as 1/2**quantization.'''

    time_sig_msgs = [ msg for msg in mid.tracks[0] if msg.type == 'time_signature' ]
    assert len(time_sig_msgs) == 1, 'No time signature found'
    time_sig = time_sig_msgs[0]
    assert time_sig.numerator == 4 and time_sig.denominator == 4, 'Not 4/4 time.'

    # Quantize the notes to a grid of time steps.
    mid = quantize(mid, quantization=quantization)
    
    # Convert the note timing and velocity to an array.
    _, track = get_note_track(mid)
    ticks_per_quarter = mid.ticks_per_beat
    time_msgs = [msg for msg in track if hasattr(msg, 'time')]
    cum_times = np.cumsum([msg.time for msg in time_msgs])

    track_len_ticks = cum_times[-1]
    if DEBUG:
        print('Track len in ticks:', track_len_ticks)
    notes = [
        (int(time * (2**quantization/4) / (ticks_per_quarter)), msg.type, msg.note, msg.velocity)
        for (time, msg) in zip(cum_times, time_msgs)
        if msg.type == 'note_on' or msg.type == 'note_off']

    num_steps = int(round(track_len_ticks / float(ticks_per_quarter)*2**quantization/4))
    normalized_num_steps = int(nearest_pow2(num_steps))
    print(normalized_num_steps)
    
    # notes.sort(key=lambda (position, note_type, note_num, velocity):(position,-velocity))

    notes.sort(key= lambda x: x[-1], reverse=True)  # sort on secondary key
    notes.sort(key= lambda x: x[0])   # sort on primary key

    if DEBUG:
        # pp = pprint.PrettyPrinter()
        print(num_steps)
        print(normalized_num_steps)
        # pp.pprint(notes)

    # midi_array = np.zeros((normalized_num_steps, len(PITCHES)*2))
    midi_array = np.zeros((normalized_num_steps, len(PITCHES), 2))
    velocity_array = np.zeros((normalized_num_steps, len(PITCHES)))
    open_msgs = defaultdict(list)

    for (position, note_type, note_num, velocity) in notes:
        if position == normalized_num_steps:
            # print 'Warning: truncating from position {} to {}'.format(position, normalized_num_steps - 1)
            position = normalized_num_steps - 1
            # continue

        if position > normalized_num_steps:
            # print 'Warning: skipping note at position {} (greater than {})'.format(position, normalized_num_steps)
            continue

        if note_type == "note_on" and velocity > 0:
            open_msgs[note_num].append((position, note_type, note_num, velocity))
            # midi_array[position, 2*PITCHES_MAP[note_num]] = 1
            # midi_array[position, 2*PITCHES_MAP[note_num]+1] = 1
            midi_array[position, PITCHES_MAP[note_num],0] = 1
            midi_array[position, PITCHES_MAP[note_num],1] = 1
            velocity_array[position, PITCHES_MAP[note_num]] = velocity
        elif note_type == 'note_off' or (note_type == 'note_on' and velocity == 0):

            note_on_open_msgs = open_msgs[note_num]

            if len(note_on_open_msgs) == 0:
                print('Bad MIDI, Note has no end time.')
                return

            stack_pos, _, _, vel = note_on_open_msgs[0]
            open_msgs[note_num] = note_on_open_msgs[1:]
            current_pos = position
            while current_pos > stack_pos:
                # if midi_array[position, PITCHES_MAP[note_num]] != 1:
                # midi_array[current_pos, 2*PITCHES_MAP[note_num]] = 0
                # midi_array[current_pos, 2*PITCHES_MAP[note_num]+1] = 1
                midi_array[current_pos, PITCHES_MAP[note_num],0] = 0
                midi_array[current_pos, PITCHES_MAP[note_num],1] = 1
                velocity_array[current_pos, PITCHES_MAP[note_num]] = vel
                current_pos -= 1

    for (position, note_type, note_num, velocity) in notes:
        if position == normalized_num_steps:
            print('Warning: truncating from position {} to {}'.format(position, normalized_num_steps - 1))
            position = normalized_num_steps - 1
            # continue

        if position > normalized_num_steps:
            # print 'Warning: skipping note at position {} (greater than {})'.format(position, normalized_num_steps)
            continue
        if note_type == "note_on" and velocity > 0:
            open_msgs[note_num].append((position, note_type, note_num, velocity))
            # midi_array[position, 2*PITCHES_MAP[note_num]] = 1
            # midi_array[position, 2*PITCHES_MAP[note_num]+1] = 1
            midi_array[position, PITCHES_MAP[note_num],0] = 1
            midi_array[position, PITCHES_MAP[note_num],1] = 1
            velocity_array[position, PITCHES_MAP[note_num]] = velocity

    assert len(midi_array) == len(velocity_array)
    return midi_array, velocity_array

# %%
def midi_to_array_one_hot_justnote(mid, quantization):
    '''Return array representation of a 4/4 time signature, MIDI object.
    Normalize the number of time steps in track to a power of 2. Then
    construct a T x N*2 array A (T = number of time steps, N = number of
    MIDI note numbers) where [A(t,n), A(t, n+1)] is the state of the note number
    at time step t.
    Arguments:
    mid -- MIDI object with a 4/4 time signature
    quantization -- The note duration, represented as 1/2**quantization.'''

    time_sig_msgs = [ msg for msg in mid.tracks[0] if msg.type == 'time_signature' ]
    assert len(time_sig_msgs) == 1, 'No time signature found'
    time_sig = time_sig_msgs[0]
    assert time_sig.numerator == 4 and time_sig.denominator == 4, 'Not 4/4 time.'

    # Quantize the notes to a grid of time steps.
    mid = quantize(mid, quantization=quantization)
    
    # Convert the note timing and velocity to an array.
    _, track = get_note_track(mid)
    ticks_per_quarter = mid.ticks_per_beat
    time_msgs = [msg for msg in track if hasattr(msg, 'time')]
    cum_times = np.cumsum([msg.time for msg in time_msgs])

    track_len_ticks = cum_times[-1]
    if DEBUG:
        print('Track len in ticks:', track_len_ticks)
    notes = [
        (int(time * (2**quantization/4) / (ticks_per_quarter)), msg.type, msg.note, msg.velocity)
        for (time, msg) in zip(cum_times, time_msgs)
        if msg.type == 'note_on' or msg.type == 'note_off']

    num_steps = int(round(track_len_ticks / float(ticks_per_quarter)*2**quantization/4))
    normalized_num_steps = int(nearest_pow2(num_steps))
    print(normalized_num_steps)
    
    # notes.sort(key=lambda (position, note_type, note_num, velocity):(position,-velocity))

    notes.sort(key= lambda x: x[-1], reverse=True)  # sort on secondary key
    notes.sort(key= lambda x: x[0])   # sort on primary key

    if DEBUG:
        # pp = pprint.PrettyPrinter()
        print(num_steps)
        print(normalized_num_steps)
        # pp.pprint(notes)

    # midi_array = np.zeros((normalized_num_steps, len(PITCHES)*2))
    midi_array = np.zeros((normalized_num_steps, len(PITCHES)))
    velocity_array = np.zeros((normalized_num_steps, len(PITCHES)))
    open_msgs = defaultdict(list)

    for (position, note_type, note_num, velocity) in notes:
        if position == normalized_num_steps:
            # print 'Warning: truncating from position {} to {}'.format(position, normalized_num_steps - 1)
            position = normalized_num_steps - 1
            # continue

        if position > normalized_num_steps:
            # print 'Warning: skipping note at position {} (greater than {})'.format(position, normalized_num_steps)
            continue

        if note_type == "note_on" and velocity > 0:
            open_msgs[note_num].append((position, note_type, note_num, velocity))
            # midi_array[position, 2*PITCHES_MAP[note_num]] = 1
            # midi_array[position, 2*PITCHES_MAP[note_num]+1] = 1
           
            midi_array[position, PITCHES_MAP[note_num]] = 1
            velocity_array[position, PITCHES_MAP[note_num]] = velocity
        elif note_type == 'note_off' or (note_type == 'note_on' and velocity == 0):

            note_on_open_msgs = open_msgs[note_num]

            if len(note_on_open_msgs) == 0:
                print('Bad MIDI, Note has no end time.')
                return

            stack_pos, _, _, vel = note_on_open_msgs[0]
            open_msgs[note_num] = note_on_open_msgs[1:]
            current_pos = position
            while current_pos > stack_pos:
                # if midi_array[position, PITCHES_MAP[note_num]] != 1:
                # midi_array[current_pos, 2*PITCHES_MAP[note_num]] = 0
                # midi_array[current_pos, 2*PITCHES_MAP[note_num]+1] = 1
                midi_array[current_pos, PITCHES_MAP[note_num]] = 1
                velocity_array[current_pos, PITCHES_MAP[note_num]] = vel
                current_pos -= 1

    for (position, note_type, note_num, velocity) in notes:
        if position == normalized_num_steps:
            print('Warning: truncating from position {} to {}'.format(position, normalized_num_steps - 1))
            position = normalized_num_steps - 1
            # continue

        if position > normalized_num_steps:
            # print 'Warning: skipping note at position {} (greater than {})'.format(position, normalized_num_steps)
            continue
        if note_type == "note_on" and velocity > 0:
            open_msgs[note_num].append((position, note_type, note_num, velocity))
            # midi_array[position, 2*PITCHES_MAP[note_num]] = 1
            # midi_array[position, 2*PITCHES_MAP[note_num]+1] = 1
            midi_array[position, PITCHES_MAP[note_num]] = 1
            velocity_array[position, PITCHES_MAP[note_num]] = velocity

    assert len(midi_array) == len(velocity_array)
    return midi_array, velocity_array

# %%
def midi_to_array_3D(mid, quantization):
    '''Return a 3D array representation of a midi :
        -First Dim is time
        -Second Dim is note
        -Third Dim is note_status : 1,0,0 hit, 0,1,0 maintained, 0,0,1 mute.'''

    time_sig_msgs = [ msg for msg in mid.tracks[0] if msg.type == 'time_signature' ]
    assert len(time_sig_msgs) == 1, 'No time signature found'
    time_sig = time_sig_msgs[0]
    assert time_sig.numerator == 4 and time_sig.denominator == 4, 'Not 4/4 time.'

    # Quantize the notes to a grid of time steps.
    mid = quantize(mid, quantization=quantization)
    
    # Convert the note timing and velocity to an array.
    _, track = get_note_track(mid)
    ticks_per_quarter = mid.ticks_per_beat
    time_msgs = [msg for msg in track if hasattr(msg, 'time')]
    cum_times = np.cumsum([msg.time for msg in time_msgs])

    track_len_ticks = cum_times[-1]
    if DEBUG:
        print('Track len in ticks:', track_len_ticks)
    notes = [
        (int(time * (2**quantization/4) / (ticks_per_quarter)), msg.type, msg.note, msg.velocity)
        for (time, msg) in zip(cum_times, time_msgs)
        if msg.type == 'note_on' or msg.type == 'note_off']

    num_steps = int(round(track_len_ticks / float(ticks_per_quarter)*2**quantization/4))
    normalized_num_steps = int(nearest_pow2(num_steps))
    
    
    # notes.sort(key=lambda (position, note_type, note_num, velocity):(position,-velocity))

    notes.sort(key= lambda x: x[-1], reverse=True)  # sort on secondary key
    notes.sort(key= lambda x: x[0])   # sort on primary key

    if DEBUG:
        # pp = pprint.PrettyPrinter()
        print(num_steps)
        print(normalized_num_steps)
        # pp.pprint(notes)

    # midi_array = np.zeros((normalized_num_steps, len(PITCHES)*2))
    midi_array = np.zeros((normalized_num_steps, len(PITCHES), 3))
    
    for i in range(len(midi_array)):
      for j in range(len(midi_array[0])):
        mid_array[i][j][2] = 1

    velocity_array = np.zeros((normalized_num_steps, len(PITCHES)))
    open_msgs = defaultdict(list)

    for (position, note_type, note_num, velocity) in notes:
        if position == normalized_num_steps:
            # print 'Warning: truncating from position {} to {}'.format(position, normalized_num_steps - 1)
            position = normalized_num_steps - 1
            # continue

        if position > normalized_num_steps:
            # print 'Warning: skipping note at position {} (greater than {})'.format(position, normalized_num_steps)
            continue

        if note_type == "note_on" and velocity > 0:
            open_msgs[note_num].append((position, note_type, note_num, velocity))
            # Note is hit

            midi_array[position, PITCHES_MAP[note_num],0] = 1
            midi_array[position, PITCHES_MAP[note_num],1] = 0
            midi_array[position, PITCHES_MAP[note_num],2] = 0
            velocity_array[position, PITCHES_MAP[note_num]] = velocity
        elif note_type == 'note_off' or (note_type == 'note_on' and velocity == 0):

            note_on_open_msgs = open_msgs[note_num]

            if len(note_on_open_msgs) == 0:
                print('Bad MIDI, Note has no end time.')
                return

            stack_pos, _, _, vel = note_on_open_msgs[0]
            open_msgs[note_num] = note_on_open_msgs[1:]
            current_pos = position
            while current_pos > stack_pos:
                # Note is hold
                midi_array[current_pos, PITCHES_MAP[note_num],0] = 0
                midi_array[current_pos, PITCHES_MAP[note_num],1] = 1
                midi_array[current_pos, PITCHES_MAP[note_num],2] = 0
                velocity_array[current_pos, PITCHES_MAP[note_num]] = vel
                current_pos -= 1
        # else:
        #   # Note is mute
        #   midi_array[current_pos, PITCHES_MAP[note_num],0] = 0
        #   midi_array[current_pos, PITCHES_MAP[note_num],1] = 0
        #   midi_array[current_pos, PITCHES_MAP[note_num],2] = 1

    for (position, note_type, note_num, velocity) in notes:
        if position == normalized_num_steps:
            print('Warning: truncating from position {} to {}'.format(position, normalized_num_steps - 1))
            position = normalized_num_steps - 1
            # continue

        if position > normalized_num_steps:
            # print 'Warning: skipping note at position {} (greater than {})'.format(position, normalized_num_steps)
            continue
        if note_type == "note_on" and velocity > 0:
            open_msgs[note_num].append((position, note_type, note_num, velocity))
            # Note is hit
            midi_array[position, PITCHES_MAP[note_num],0] = 1
            midi_array[position, PITCHES_MAP[note_num],1] = 0
            midi_array[position, PITCHES_MAP[note_num],2] = 0
            velocity_array[position, PITCHES_MAP[note_num]] = velocity

    assert len(midi_array) == len(velocity_array)
    return midi_array, velocity_array

# %%
def transform_2D_numpy_to3D_numpy(array):
  array_3D = np.zeros((len(array), len(array[0]), 3))
  for i in range(len(array)):
    for j in range(len(array[0])):
      
      is_hit = array[i][j][0] == 1
      is_played =  array[i][j][1] == 1

      if is_hit:
        array_3D[i][j][0] = 1
      elif is_played:
        array_3D[i][j][1] = 1
      else:
        array_3D[i][j][2] = 1
  
  return array_3D

# %%
# !unzip classical.zip
# Out:
# Archive:  jazz.zip
#    creating: jazz/
#   inflating: jazz/4thAvenueTheme.mid
#   inflating: jazz/A Sleepin' Bee.mid
#   inflating: jazz/accustomed.mid
#   inflating: jazz/afine-1.mid
#   inflating: jazz/afine-2.mid
#   inflating: jazz/Aghostofachance.mid
#   inflating: jazz/AHouseis.mid
#   inflating: jazz/Alabama.mid
#   inflating: jazz/alfiepno.mid
#   inflating: jazz/Aliceinw.mid
#   inflating: jazz/All The Things You Are.mid
#   inflating: jazz/AllOfMe2.mid
#   inflating: jazz/alltheth.mid
#   inflating: jazz/AllTheThings Reharmonized.mid
#   inflating: jazz/AllTheThings V2.mid
#   inflating: jazz/alone.mid
#   inflating: jazz/along.mid
#   inflating: jazz/angela.mid
#   inflating: jazz/Anthropology.mid
#   inflating: jazz/ARemarkYouMade.mid
#   inflating: jazz/Ask Me Now 2.mid
#   inflating: jazz/atIknew.mid
#   inflating: jazz/atrain2.mid
#   inflating: jazz/autleave.mid
#   inflating: jazz/Autumn In NY.mid
#   inflating: jazz/AutumnL.mid
#   inflating: jazz/AutumnLeaves.mid
#   inflating: jazz/Baby its Cold outside.mid
#   inflating: jazz/Bach Prelude No 1 (Ave Maria).mid
#   inflating: jazz/Basiervg.mid
#   inflating: jazz/bdazhed.mid
#   inflating: jazz/beacon.mid
#   inflating: jazz/Beautiful Love (Doug McKenzie).mid
#   inflating: jazz/Beautiful_Love.mid
#   inflating: jazz/Begin The Beguine.mid
#   inflating: jazz/Bess You Is.mid
#   inflating: jazz/bethlehem.mid
#   inflating: jazz/bewitched.mid
#   inflating: jazz/BigMess.mid
#   inflating: jazz/billiesb.mid
#   inflating: jazz/birdland.mid
#   inflating: jazz/bl4alice.mid
#   inflating: jazz/Blameiton.mid
#   inflating: jazz/Blue room midi file.mid
#   inflating: jazz/Bluenboo.mid
#   inflating: jazz/blues4npage.mid
#   inflating: jazz/bluesette.mid
#   inflating: jazz/BluesForTrane.mid
#   inflating: jazz/BlueTrain.mid
#   inflating: jazz/Blue_In_Green.mid
#   inflating: jazz/BPowell.mid
#   inflating: jazz/BrazilianSuite.mid
#   inflating: jazz/Brazillike.mid
#   inflating: jazz/broadwa2.mid
#   inflating: jazz/broadway.mid
#   inflating: jazz/budo.mid
#   inflating: jazz/But Beautifulsolo.mid
#   inflating: jazz/By Myself3.mid
#   inflating: jazz/Bymyself.mid
#   inflating: jazz/Cantabile 2.mid
#   inflating: jazz/caravan.mid
#   inflating: jazz/Cast Your Fate.mid
#   inflating: jazz/Chameleon.mid
#   inflating: jazz/Chelsea Bridge.mid
#   inflating: jazz/cherokee.mid
#   inflating: jazz/chromBlinF.mid
#   inflating: jazz/cinema.mid
#   inflating: jazz/cjamblusx.mid
#   inflating: jazz/Clifford1.mid
#   inflating: jazz/Come Rain or Come Shine duo.mid
#   inflating: jazz/Come Rain or Come Shine V1.mid
#   inflating: jazz/comerain.mid
#   inflating: jazz/comesun.mid
#   inflating: jazz/conalma.mid
#   inflating: jazz/couldwrite.mid
#   inflating: jazz/Cubano Chant 2.mid
#   inflating: jazz/Cute.mid
#   inflating: jazz/DancingontheCeiling.mid
#   inflating: jazz/Danny Boy.mid
#   inflating: jazz/Dannyboy.mid
#   inflating: jazz/Day Dream.mid
#   inflating: jazz/daybyday.mid
#   inflating: jazz/DaysOf.mid
#   inflating: jazz/dearlybeloved.mid
#   inflating: jazz/DeepPurple.mid
#   inflating: jazz/Desafinado.mid
#   inflating: jazz/Desafinado78.mid
#   inflating: jazz/desire.mid
#   inflating: jazz/Detour ahead.mid
#   inflating: jazz/Do I Love You Because you're Beautiful.mid
#   inflating: jazz/DolphinDance.mid
#   inflating: jazz/dolphindance3.mid
#   inflating: jazz/dolphnst.mid
#   inflating: jazz/don-lee2.mid
#   inflating: jazz/Dreamsville.mid
#   inflating: jazz/DstMeT.mid
#   inflating: jazz/eastofthesun.mid
#   inflating: jazz/Easy Living 3.mid
#   inflating: jazz/EasytoLove2.mid
#   inflating: jazz/Effendi - McCoy Tyner.mid
#   inflating: jazz/estate.mid
#   inflating: jazz/Exactly Like You.mid
#   inflating: jazz/eyeotbeh.mid
#   inflating: jazz/Falling Grace .mid
#   inflating: jazz/Falling in Love with Love trio.mid
#   inflating: jazz/fever2.mid
#   inflating: jazz/flybynight.mid
#   inflating: jazz/foreplayx.mid
#   inflating: jazz/ForSentimentalReasons.mid
#   inflating: jazz/four2.mid
#   inflating: jazz/FreckleFace.mid
#   inflating: jazz/funkallero.mid
#   inflating: jazz/Gaviota trio 2.mid
#   inflating: jazz/Goin'_Home_(Real_Time)_(Antonin_Dvorak).mid
#   inflating: jazz/Gone with the wind.mid
#   inflating: jazz/gonewind.mid
#   inflating: jazz/Green Dolph solo.mid
#   inflating: jazz/grelots.mid
#   inflating: jazz/GrooveYard.mid
#   inflating: jazz/grooving_hard.mid
#   inflating: jazz/Have You Met - duet.mid
#   inflating: jazz/Have You Met Miss Jones - latin.mid
#   inflating: jazz/HaveUMMsJ.mid
#   inflating: jazz/hayBurner.mid
#   inflating: jazz/HOW.mid
#   inflating: jazz/howdsolo.mid
#   inflating: jazz/HowkumU.mid
#   inflating: jazz/HushABye.mid
#   inflating: jazz/hwdptrio.mid
#   inflating: jazz/Hymn To Freedom.mid
#   inflating: jazz/I Concentrate on You.mid
#   inflating: jazz/I Cover the Waterfront - solo.mid
#   inflating: jazz/I fall in Love Too Easily.mid
#   inflating: jazz/I Fall in Love v2.mid
#   inflating: jazz/I Hear a Rhapsody.mid
#   inflating: jazz/I Thought About You (Doug McKenzie).mid
#   inflating: jazz/I'll Close My Eyes 2.mid
#   inflating: jazz/I'm Confessin' - solo.mid
#   inflating: jazz/IALikeBeingInLove.mid
#   inflating: jazz/Icantgetstarted.mid
#   inflating: jazz/IConcOnY.mid
#   inflating: jazz/ICWABook.mid
#   inflating: jazz/Idkwhtime.mid
#   inflating: jazz/idmathing.mid
#   inflating: jazz/if i loved you.mid
#   inflating: jazz/IfIshouldLeaveYou.mid
#   inflating: jazz/IfIwere.mid
#   inflating: jazz/If_bell.mid
#   inflating: jazz/IGrownAcc2HF.mid
#   inflating: jazz/Indiana.mid
#   inflating: jazz/ineverknew.mid
#   inflating: jazz/INVITATION.mid
#   inflating: jazz/ISaidItbefore.mid
#   inflating: jazz/Isfahan (Elf).mid
#   inflating: jazz/ishouldcare2.mid
#   inflating: jazz/Isn_t_it_Romantic.mid
#   inflating: jazz/israel.mid
#   inflating: jazz/It Could Happen - piano trio.mid
#   inflating: jazz/It Could Happen V2.mid
#   inflating: jazz/It'sAlmostLikeBeingInLove.mid
#   inflating: jazz/ItCouldHappenGM.mid
#   inflating: jazz/Itdon'tmeanathing.mid
#   inflating: jazz/Its Easy to Remember.mid
#   inflating: jazz/Its theTalk Of The Town - solo.mid
#   inflating: jazz/I_Wont_Dance_R.mid
#   inflating: jazz/joyed.mid
#   inflating: jazz/JoySpring.mid
#   inflating: jazz/Just a Gigolo.mid
#   inflating: jazz/Just Friends Trio.mid
#   inflating: jazz/Justfren.mid
#   inflating: jazz/justfrien solo.mid
#   inflating: jazz/killerjoe.mid
#   inflating: jazz/KingandI.mid
#   inflating: jazz/Ladies in Mercedes.mid
#   inflating: jazz/ladybegood.mid
#   inflating: jazz/laura.mid
#   inflating: jazz/lazybird.mid
#   inflating: jazz/LBirdland.mid
#   inflating: jazz/Little Girl Blue.mid
#   inflating: jazz/Long Ago and Far away - 3 versions.mid
#   inflating: jazz/LookfortheSilverLining.mid
#   inflating: jazz/Love walked In.mid
#   inflating: jazz/lovercome piano.mid
#   inflating: jazz/LoveWalked.mid
#   inflating: jazz/Lovewalkedin.mid
#   inflating: jazz/LushLife  trio.mid
#   inflating: jazz/Mad About the Boy.mid
#   inflating: jazz/maidenvoyage.mid
#   inflating: jazz/maisquenada.mid
#   inflating: jazz/Make Someone Happy.mid
#   inflating: jazz/manteca.mid
#   inflating: jazz/McKenzie-Ishouldcare2.mid
#   inflating: jazz/McKenzie-secret love.mid
#   inflating: jazz/MembersOnly.mid
#   inflating: jazz/Memories of Paris.mid
#   inflating: jazz/merryxmas.mid
#   inflating: jazz/Mnksmd.mid
#   inflating: jazz/moanin.mid
#   inflating: jazz/Mood Indigo - solo.mid
#   inflating: jazz/Moon and Sand.mid
#   inflating: jazz/moonlightinvermont.mid
#   inflating: jazz/moreicu.mid
#   inflating: jazz/move.mid
#   inflating: jazz/mwv_blues.mid
#   inflating: jazz/My Romance.mid
#   inflating: jazz/My Shining Hour.mid
#   inflating: jazz/my1aonly.mid
#   inflating: jazz/MyFoolishHeart.mid
#   inflating: jazz/MyFunny3.mid
#   inflating: jazz/myheartstoodstill edited a bit.mid
#   inflating: jazz/Myoneand.mid
#   inflating: jazz/MyShiningHoursolo.mid
#   inflating: jazz/NARDIS.mid
#   inflating: jazz/nardis2.mid
#   inflating: jazz/NewOrleans.mid
#   inflating: jazz/nica.mid
#   inflating: jazz/Nicadream.mid
#   inflating: jazz/NoMoreBlues.mid
#   inflating: jazz/Nutville.mid
#   inflating: jazz/Old Folks.mid
#   inflating: jazz/Old Man River.mid
#   inflating: jazz/olddevilmoon.mid
#   inflating: jazz/On Green Dolphin 4.mid
#   inflating: jazz/ontheotherhand.mid
#   inflating: jazz/OurLove_x.mid
#   inflating: jazz/Out of Nowhere 1.mid
#   inflating: jazz/Out of Nowhere 2.mid
#   inflating: jazz/Out of Nowhere 3.mid
#   inflating: jazz/Over the rain trio.mid
#   inflating: jazz/peace.mid
#   inflating: jazz/Peanut Vendor (El Manisero).mid
#   inflating: jazz/peanutsg.mid
#   inflating: jazz/penthouse s.mid
#   inflating: jazz/pentupHouse.mid
#   inflating: jazz/periscope.mid
#   inflating: jazz/phasedance.mid
#   inflating: jazz/Pick yourself.mid
#   inflating: jazz/porgy1.mid
#   inflating: jazz/porgy2.mid
#   inflating: jazz/Prelude to a kiss.mid
#   inflating: jazz/prelude.mid
#   inflating: jazz/Pure Imagination.mid
#   inflating: jazz/quick.mid
#   inflating: jazz/Remember - solo jazz piano.mid
#   inflating: jazz/Renewaltrio.mid
#   inflating: jazz/riofunk.mid
#   inflating: jazz/rndmngt.mid
#   inflating: jazz/roofgdn2.mid
#   inflating: jazz/SammyWalked.mid
#   inflating: jazz/santa.mid
#   inflating: jazz/SatinDol.mid
#   inflating: jazz/satin_doll.mid
#   inflating: jazz/send in the clowns.mid
#   inflating: jazz/sentmood.mid
#   inflating: jazz/Serenata solo.mid
#   inflating: jazz/shawnuff.mid
#   inflating: jazz/Shenandoah.mid
#   inflating: jazz/shiny.mid
#   inflating: jazz/shinystockings.mid
#   inflating: jazz/simplelife.mid
#   inflating: jazz/Since We Met Jazz Kit.mid
#   inflating: jazz/sinceIfell.mid
#   inflating: jazz/sixteengoing.mid
#   inflating: jazz/SoInlove - trio version.mid
#   inflating: jazz/SoinLovesolo.mid
#   inflating: jazz/solar.mid
#   inflating: jazz/Some day My Prince.mid
#   inflating: jazz/Some Other Time.mid
#   inflating: jazz/something wonderful.mid
#   inflating: jazz/sonata4vc.mid
#   inflating: jazz/songfor.mid
#   inflating: jazz/sonnymoo.mid
#   inflating: jazz/soon.mid
#   inflating: jazz/SophisticatedLady.mid
#   inflating: jazz/SoulEyessolo.mid
#   inflating: jazz/Speak Low (Doug McKenzie).mid
#   inflating: jazz/speaklo3.mid
#   inflating: jazz/Spring Is Here - Bill Evans chords.mid
#   inflating: jazz/Spring is Here 2 (K Barron).mid
#   inflating: jazz/Spring Is Here2-Bill Evans chords.mid
#   inflating: jazz/star eyes.mid
#   inflating: jazz/stella2.mid
#   inflating: jazz/stiltime.mid
#   inflating: jazz/stolen.mid
#   inflating: jazz/stormyweather.mid
#   inflating: jazz/StrangeMeadowlark.mid
#   inflating: jazz/Strollin'.mid
#   inflating: jazz/StWeather.mid
#   inflating: jazz/Summer wind 2.mid
#   inflating: jazz/Surrey medley.mid
#   inflating: jazz/sushi.mid
#   inflating: jazz/Sweet1.mid
#   inflating: jazz/SweetAndLovely.mid
#   inflating: jazz/Sweetlorraine.mid
#   inflating: jazz/taketheatrain.mid
#   inflating: jazz/TakinAC.mid
#   inflating: jazz/TakinACh.mid
#   inflating: jazz/Taking a Chance On Love - Solo piano.mid
#   inflating: jazz/That Ole Devil Called Love.mid
#   inflating: jazz/The End of a Love Affair.mid
#   inflating: jazz/The Masquerade is Over.mid
#   inflating: jazz/The Way You look trio.mid
#   inflating: jazz/TheDuke.mid
#   inflating: jazz/TheManILove.mid
#   inflating: jazz/TheManThatGotAway.mid
#   inflating: jazz/TheOddCpl.mid
#   inflating: jazz/There will never be another you.mid
#   inflating: jazz/thereisnogreaterlove.mid
#   inflating: jazz/TheSongisYoutrio.mid
#   inflating: jazz/They say its wonderful.mid
#   inflating: jazz/Thingsaintwhattheyusedtobe.mid
#   inflating: jazz/This Time the Dreams on Me.mid
#   inflating: jazz/thiscantbelove.mid
#   inflating: jazz/Time after Time 2.mid
#   inflating: jazz/Time remembered.mid
#   inflating: jazz/timerem2.mid
#   inflating: jazz/TooYoungtogoSteady.mid
#   inflating: jazz/toss_up.mid
#   inflating: jazz/Tryalittle21.mid
#   inflating: jazz/tunisia.mid
#   inflating: jazz/tunisia2.mid
#   inflating: jazz/turnoutthestars.mid
#   inflating: jazz/Two For The Road 5.mid
#   inflating: jazz/Very Early solo piano.mid
#   inflating: jazz/Warmvalleysolo.mid
#   inflating: jazz/What is there to say.mid
#   inflating: jazz/When I Fall in Love.mid
#   inflating: jazz/Where is Love - solo.mid
#   inflating: jazz/whisper.mid
#   inflating: jazz/whispernot.mid
#   inflating: jazz/whydidi.mid
#   inflating: jazz/WhyDoILoveYou.mid
#   inflating: jazz/Witchcraft.mid
#   inflating: jazz/world.mid
#   inflating: jazz/WWHappens.mid
#   inflating: jazz/wylhg.mid
#   inflating: jazz/xmas.mid
#   inflating: jazz/xtracrispy.mid
#   inflating: jazz/YBSN2CH2.mid
#   inflating: jazz/Yesterday.mid
#   inflating: jazz/Yesterdays1.mid
#   inflating: jazz/You Are So Beautiful The Grand.mid
#   inflating: jazz/youdbe.mid
#   inflating: jazz/youdontknow trio.mid
#   inflating: jazz/youhavechanged.mid
#   inflating: jazz/Young and Foolish.mid
#   inflating: jazz/youtookadvantageofme.mid
#   inflating: jazz/Zingaro - Jobim.mid
#   inflating: jazz/Zip-A-Dee-Doo-Dah.mid

# %%
import os

# %%
counter = 0
fail_count = 0
for filename in os.listdir("/content/classical"):
  try:
    mid = MidiFile( "/content/classical/" + filename)
    array = midi_to_array_one_hot(mid, 4)[0]
    array3D = transform_2D_numpy_to3D_numpy(array)
    save_path = "/content/classical3D_nice/classical_content_" + str(counter)
    np.save(save_path, array3D)
    counter +=1
  except:
    fail_count +=1
# Out:
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1536
# 3072
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 2048
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 8192
# 6144
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 6144
# Bad MIDI, Note has no end time.
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 8192
# 1536
# 8192
# 4096
# Bad MIDI. Cannot have note off event before note on event
# 12288
# 8192
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1536
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# 4096
# 4096
# 3072
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# 2048
# Bad MIDI, Note has no end time.
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 1024
# Bad MIDI. Cannot have note off event before note on event
# 256
# Warning: truncating from position 256 to 255
# Warning: truncating from position 256 to 255
# Warning: truncating from position 256 to 255
# Warning: truncating from position 256 to 255
# Bad MIDI, Note has no end time.
# 6144
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 768
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 384
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1024
# 1024
# Bad MIDI, Note has no end time.
# 2048
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# 512
# 6144
# 384
# Bad MIDI, Note has no end time.
# 3072
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# 2048
# Bad MIDI. Cannot have note off event before note on event
# 2048
# Warning: truncating from position 2048 to 2047
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# 2048
# 1536
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 3072
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 2048
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 6144
# 6144
# 2048
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 2048
# 1024
# 2048
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# 512
# 3072
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# 4096
# Warning: truncating from position 4096 to 4095
# Warning: truncating from position 4096 to 4095
# Warning: truncating from position 4096 to 4095
# Warning: truncating from position 4096 to 4095
# Warning: truncating from position 4096 to 4095
# Warning: truncating from position 4096 to 4095
# Warning: truncating from position 4096 to 4095
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1024
# 1024
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 192
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1536
# 768
# 768
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Bad MIDI, Note has no end time.
# 1024
# 8192
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 8192
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# 768
# 8192
# Warning: truncating from position 8192 to 8191
# Warning: truncating from position 8192 to 8191
# Warning: truncating from position 8192 to 8191
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# 1536
# 1536
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 3072
# Warning: truncating from position 3072 to 3071
# Warning: truncating from position 3072 to 3071
# 1536
# Bad MIDI, Note has no end time.
# 16384
# Bad MIDI, Note has no end time.
# 1024
# 1536
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Bad MIDI, Note has no end time.
# 1536
# 6144
# Warning: truncating from position 6144 to 6143
# Warning: truncating from position 6144 to 6143
# Warning: truncating from position 6144 to 6143
# Warning: truncating from position 6144 to 6143
# Warning: truncating from position 6144 to 6143
# 2048
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Bad MIDI, Note has no end time.
# 1024
# Warning: truncating from position 1024 to 1023
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# 2048
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# 1536
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 2048
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 6144
# 2048
# 1536
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 1536
# Bad MIDI, Note has no end time.
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 2048
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# 1536
# Bad MIDI, Note has no end time.
# 2048
# Warning: truncating from position 2048 to 2047
# Bad MIDI, Note has no end time.
# 512
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# 8192
# Warning: truncating from position 8192 to 8191
# Warning: truncating from position 8192 to 8191
# Warning: truncating from position 8192 to 8191
# Warning: truncating from position 8192 to 8191
# Warning: truncating from position 8192 to 8191
# Warning: truncating from position 8192 to 8191
# 192
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Warning: truncating from position 192 to 191
# Bad MIDI, Note has no end time.
# 8192
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# 768
# 1536
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Bad MIDI, Note has no end time.
# 768
# 1536
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# 2048
# 4096
# Bad MIDI, Note has no end time.
# 6144
# Bad MIDI, Note has no end time.
# 1536
# 2048
# 4096
# Bad MIDI, Note has no end time.
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Bad MIDI, Note has no end time.
# 8192
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 512
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# 16384
# Warning: truncating from position 16384 to 16383
# Warning: truncating from position 16384 to 16383
# Warning: truncating from position 16384 to 16383
# Warning: truncating from position 16384 to 16383
# Warning: truncating from position 16384 to 16383
# Warning: truncating from position 16384 to 16383
# Warning: truncating from position 16384 to 16383
# Warning: truncating from position 16384 to 16383
# Warning: truncating from position 16384 to 16383
# Warning: truncating from position 16384 to 16383
# Bad MIDI, Note has no end time.
# 3072
# 2048
# Warning: truncating from position 2048 to 2047
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1024
# 6144
# Warning: truncating from position 6144 to 6143
# Warning: truncating from position 6144 to 6143
# Warning: truncating from position 6144 to 6143
# Warning: truncating from position 6144 to 6143
# Warning: truncating from position 6144 to 6143
# 1536
# 4096
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1536
# 1024
# 1536
# 1536
# Bad MIDI. Cannot have note off event before note on event
# 6144
# 2048
# 2048
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# 768
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 2048
# 768
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1024
# 1024
# Warning: truncating from position 1024 to 1023
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 768
# Bad MIDI, Note has no end time.
# 2048
# Bad MIDI, Note has no end time.
# 512
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# 8192
# Bad MIDI, Note has no end time.
# 2048
# 1536
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 384
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 768
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# 4096
# Bad MIDI, Note has no end time.
# 3072
# 512
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Bad MIDI. Cannot have note off event before note on event
# 1024
# 4096
# 768
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# 2048
# 256
# 512
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# Warning: truncating from position 512 to 511
# 1536
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1536
# 2048
# Bad MIDI, Note has no end time.
# 3072
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Bad MIDI. Cannot have note off event before note on event
# 3072
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1536
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# Warning: truncating from position 1536 to 1535
# 4096
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 12288
# Bad MIDI. Cannot have note off event before note on event
# 8192
# 1536
# 512
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 8192
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event
# 6144
# 3072
# 512
# Bad MIDI, Note has no end time.
# 1536
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 8192
# 2048
# 1024
# Warning: truncating from position 1024 to 1023
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1024
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# Warning: truncating from position 1024 to 1023
# 768
# 1536
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1536
# 1536
# Bad MIDI. Cannot have note off event before note on event
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 4096
# 768
# Warning: truncating from position 768 to 767
# Warning: truncating from position 768 to 767
# Bad MIDI. Cannot have note off event before note on event
# 384
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# 384
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Warning: truncating from position 384 to 383
# Bad MIDI, Note has no end time.
# 12288
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 1536
# 3072
# 12288
# Warning: truncating from position 12288 to 12287
# Warning: truncating from position 12288 to 12287
# Warning: truncating from position 12288 to 12287
# Warning: truncating from position 12288 to 12287
# Warning: truncating from position 12288 to 12287
# Warning: truncating from position 12288 to 12287
# Warning: truncating from position 12288 to 12287
# Warning: truncating from position 12288 to 12287
# Warning: truncating from position 12288 to 12287
# Warning: truncating from position 12288 to 12287
# Bad MIDI, Note has no end time.
# 2048
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# 3072
# 384
# Bad MIDI, Note has no end time.
# 768
# 2048
# 2048
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# 2048
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Warning: truncating from position 2048 to 2047
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI, Note has no end time.
# Bad MIDI. Cannot have note off event before note on event

# %%
# !zip -r /content/classical3D.zip /content/classical3D
